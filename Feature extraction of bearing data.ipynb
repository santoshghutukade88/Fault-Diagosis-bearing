# %%
import numpy as np
import pandas as pd
import os
import math
import stat

# %%
allfolders=os.listdir('E:\PYTHON\projects\Data set')

# %%
path='E:\PYTHON\projects\Data set'

# %%
allfiles=os.listdir('E:\PYTHON\projects\Data set\Clearance')

# %%
final1=pd.DataFrame(columns=('mean','kurtosis','skewness','variance','STD','fault'))

# %%
z1=[]
z2=[]
z3=[]
z4=[]
z5=[]
z6=[]
for i in allfolders: 
    allfiles=os.listdir('E:\PYTHON\projects\Data set'+'\\'+ i)
    for j in allfiles:
        df=pd.read_excel(path + '\\'+i+'\\'+ j)
        z1.append(df.iloc[:,1].mean())
        z2.append(df.iloc[:,1].kurtosis())
        z3.append(df.iloc[:,1].skew())
        z4.append(df.iloc[:,1].var())
        z5.append(df.iloc[:,1].std())
        z6.append(i)
        
final=pd.DataFrame({'mean':z1,'kurtosis':z2,'skewness':z3,'variance':z4,'STD':z5,'fault':z6})

# %%
final
# Out:
#         mean    kurtosis   skewness  variance       STD       fault
# 0   0.010431  258.765724  14.156161  0.001018  0.031910   Clearance
# 1   0.008817  396.769508  16.359617  0.000697  0.026407   Clearance
# 2   0.011659  391.342401  17.236296  0.001419  0.037674   Clearance
# 3   0.014084  226.149227  11.952710  0.000956  0.030917   Clearance
# 4   0.008223  316.548694  15.085642  0.000911  0.030185   Clearance
# ..       ...         ...        ...       ...       ...         ...
# 61  0.011589  195.584900  11.152434  0.000498  0.022315  Unbalanced
# 62  0.012411  166.028117  10.135176  0.000539  0.023220  Unbalanced
# 63  0.011950  188.542935  10.466138  0.000479  0.021895  Unbalanced
# 64  0.012255  183.789828  10.615628  0.000545  0.023347  Unbalanced
# 65  0.012255  198.951788  10.839147  0.000504  0.022442  Unbalanced
#
# [66 rows x 6 columns]
